# %% [markdown]
# ## Level 2:
# **Task 1: Table Booking and Online Delivery**

# %%
# import necessary library 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# **Step1: Obtain the dataset and perform data cleaning and analyze**

# %%
resturant = pd.read_csv("Dataset .csv")
resturant
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
resturant.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
resturant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Count the number of resturants offering table booking and online booking
count1 = resturant['Has Online delivery'].value_counts().get('Yes',0)
count2 = resturant['Has Table booking'].value_counts().get('Yes', 0)

# %%
# print(count1)
# print(count2)

# %%
print(f"The number of online delivery = ",count1)
print(f"The number of table booking =",count2)
# Out:
# The number of online delivery =  2451
# The number of table booking = 1158

# %%
# total_resturants = len(resturant)
# total_resturants

# %%
print(f"The total number of resturant operating = ", total_resturants)
# Out:
# The total number of resturant operating =  9551

# %% [markdown]
# **Step2: Cal the percentage of resturants offering online delivery and table booking**

# %%
# percentage of online delivery
percent_online_delivery = int((count1 / total_resturants) * 100)

# percentage of table booking 
percent_table_booking = int((count2 / total_resturants) * 100 )

print(f"Percentage of resturants offering online delivery : {percent_online_delivery}%")
print(f"Percentage of resturants offering table booking: {percent_table_booking}%")
# Out:
# Percentage of resturants offering online delivery : 25%
# Percentage of resturants offering table booking: 12%

# %%
print(type(percent_online_delivery))
# Out:
# <class 'int'>

# %% [markdown]
# **Step3: Compare the average ratings of restaurants with table booking and those without**

# %%
# Count the ratings of table booking and without 
table_with_rating = resturant[resturant['Has Table booking'].str.lower()=='yes']
table_withou_rating = resturant[resturant['Has Table booking'].str.lower()=='no']
print(table_count1, table_count2)
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 2           6300002                    Heat - Edsa Shangri-La           162
# 4           6314302                               Sambo Kojin           162
# 6           6300781                                Buffet 101           162
# ...             ...                                       ...           ...
# 9403        6800569                                Chaophraya           215
# 9415        6801873  Mr Cooper's House & Garden - The Midland           215
# 9431       18295472                                  Gymkhana           166
# 9450        6400621                           Nobu - One&Only           189
# 9463        6516766                              The National           189
#
# ...

# %%
# Get the average ratings
avg_rating_with_table_booking = table_with_rating['Aggregate rating'].mean()
avg_rating_without_table_booking = table_withou_rating['Aggregate rating'].mean()

print(f"Average ratings of table booking: {avg_rating_with_table_booking}") 
print(f"Average rating without table booking: {avg_rating_without_table_booking}")
# Out:
# Average ratings of table booking: 3.4419689119170984
# Average rating without table booking: 2.559358989634219

# %% [markdown]
# **Step4: Analyze online delivery availability among resturants with different price ranges**

# %%
# Get the price range for online delivery 
online_delivery_price_range = resturant[resturant['Price range']==True]['Price range']
print(f"Online delivery availability by price range:{online_delivery_price_range}")
# Out:
# Online delivery availability by price range:23      1
# 30      1
# 83      1
# 84      1
# 85      1
#        ..
# 9319    1
# 9337    1
# 9338    1
# 9353    1
# 9408    1
# Name: Price range, Length: 4444, dtype: int64

# %%
delivery_price = resturant.groupby('Price range')
delivery_price

# %%
resturant['Price range']
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
online_delivery_price_range = resturant.groupby('Has Online delivery')['Price range'].sum()

# %%
online_delivery_price_range
# Out:
# Has Online delivery
# No     12520
# Yes     4718
# Name: Price range, dtype: int64

# %%
print(online_delivery_price_range)
# Out:
# Has Online delivery
# No     12520
# Yes     4718
# Name: Price range, dtype: int64

# %% [markdown]
# **Step5: Visualize the result of online delivery price range using bar plot**

# %%
# Create a bar graph to visualize

plt.figure(figsize=(12,8), dpi=200)
plt.bar(online_delivery_price_range.index,
        online_delivery_price_range.values)
plt.xlabel('Online delivery',color='brown') 
plt.ylabel('Price range',color='blue')
plt.title('Online Delivery Availability by Price Range')
plt.show()
